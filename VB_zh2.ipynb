-- %%
select *
from szallashely
-- Out:
-- (21 rows affected)
-- Total execution time: 00:00:00.048
-- ...

-- %%
select szoba_fk
,       foglalas_pk
,       datediff(day, mettol, meddig) as 'foglalas idotartam'
,       iif(lag(datediff(day, mettol, meddig)) over(partition by szoba_fk order by foglalas_pk) is null, 0, 
lag(datediff(day, mettol, meddig)) over(partition by szoba_fk order by foglalas_pk)) as 'elozo foglalas'
from foglalas
-- Out:
-- (1027 rows affected)
-- Total execution time: 00:00:00.017
-- ...

-- %%
select tipus, hely
,       round(avg(CSILLAGOK_SZAMA) over(partition by tipus), 2)
,       round(avg(CSILLAGOK_SZAMA) over(partition by hely), 2)

from szallashely sz
where SZALLAS_ID not in (select szallas_id
from szallashely sz2
where szallas_nev like '%-%')
-- Out:
-- (20 rows affected)
-- Total execution time: 00:00:00.006
-- ...

-- %%
select szallas_id
from szallashely
where szallas_nev like '%-%'
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.008
-- <table><tr><th>szallas_id</th><th>szallas_nev</th></tr><tr><td>1</td><td>Sába-Ház</td></tr></table>
